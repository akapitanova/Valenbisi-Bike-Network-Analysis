# %% [markdown]
# # Data clustering based on stations' position
# One of the way how to cluster stations is based on their position. The idea behind it is that stations in neighbourhood will have similar behaviour - number of usage in time.

# %%
import pandas as pd

# %% [markdown]
# ## Load data

# %%
data = pd.read_csv('./datasets/dataset.csv', sep=',')
data.head()
# Out:
# /tmp/ipykernel_87181/3176350646.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('./datasets/dataset.csv', sep=',')
#       gid  available  free  total  w_temp           w_sky  w_precip  w_humid  \
# 0  901622         18     2     20    12.0  Cielo cubierto       0.0     66.0
# 1  901673          9    29     38    12.0  Cielo cubierto       0.0     66.0
# 2  901677         15     8     23    12.0  Cielo cubierto       0.0     66.0
# 3  901679          3    18     21    12.0  Cielo cubierto       0.0     66.0
# 4  901627         15     4     20    12.0  Cielo cubierto       0.0     66.0
#
#    w_wind_speed  w_clouds  ...  dayofweek day_category day_motive        lat  \
# 0           6.8      88.0  ...   Thursday  Working day        NaN  39.458781
# 1           6.8      88.0  ...   Thursday  Working day        NaN  39.472282
# 2           6.8      88.0  ...   Thursday  Working day        NaN  39.473068
# 3           6.8      88.0  ...   Thursday  Working day        NaN  39.471344
# 4           6.8      88.0  ...   Thursday  Working day        NaN  39.456512
#
#        long             datetime occupancy   vacancy  bikes_diff  free_diff
# 0 -0.358658  2022-12-01 02:00:00  0.900000  0.100000         0.0        0.0
# 1 -0.343809  2022-12-01 02:00:00  0.236842  0.763158         0.0        0.0
# 2 -0.343132  2022-12-01 02:00:00  0.652174  0.347826         0.0        0.0
# 3 -0.340484  2022-12-01 02:00:00  0.142857  0.857143         0.0        0.0
# 4 -0.355418  2022-12-01 02:00:00  0.750000  0.200000         0.0        0.0
#
# [5 rows x 21 columns]

# %% [markdown]
# # Data clustering based on location

# %%
locations = data[["gid", "lat", "long"]].drop_duplicates()
print(locations.head())

if len(locations) != locations.gid.unique().shape[0]:
    print("some stations has multiple locations")
# Out:
#       gid        lat      long
# 0  901622  39.458781 -0.358658
# 1  901673  39.472282 -0.343809
# 2  901677  39.473068 -0.343132
# 3  901679  39.471344 -0.340484
# 4  901627  39.456512 -0.355418

# %%
from sklearn.cluster import KMeans

# Selecting lat and long columns for clustering
X = locations[['lat', 'long']]

# Number of clusters
k_clusters = 7

# KMeans
kmeans = KMeans(n_clusters=k_clusters)
kmeans.fit(X)

# Adding cluster labels
locations['cluster'] = kmeans.labels_

print(locations)
# Out:
# /home/anna/anaconda3/envs/smc_env/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
#         gid        lat      long  cluster
# 0    901622  39.458781 -0.358658        1
# 1    901673  39.472282 -0.343809        3
# 2    901677  39.473068 -0.343132        3
# 3    901679  39.471344 -0.340484        3
# 4    901627  39.456512 -0.355418        1
# ..      ...        ...       ...      ...
# 271  901651  39.460380 -0.333531        3
# 272  901649  39.461952 -0.338721        3
# 273  901647  39.458860 -0.336798        3
# 274  901657  39.484973 -0.365667        0
# 275  901663  39.477585 -0.366970        0
#
# [276 rows x 4 columns]

# %%
import folium

# array of all the stations in the network
stations = data.gid.unique()

# extracting information about each station's total number of available racks
stations_size = data.groupby(["gid"])["total"].mean()

f = folium.Figure(width=700, height=700)
map = folium.Map(location=[39.4502730411, -0.333362], tiles='OpenStreetMap', zoom_start=12)

colors = ['blue', 'red', 'green', 'orange', 'purple', 'darkblue', 'brown', 'cyan', 'black', 'darkred', 'gray']

for station in stations:
    folium.Circle(
        location=[locations[locations.gid == station]['lat'].iloc[0], locations[locations.gid == station]['long'].iloc[0]],
        color=colors[locations[locations.gid == station]['cluster'].iloc[0]],
        radius=5 * stations_size.loc[station],
        fill=True,
        opacity=0.8,
        fill_opacity=0.2,
        tooltip='Station {} | Docks: {} | Cluster: {}'.format(
            station, stations_size.loc[station], locations[locations.gid == station]['cluster'].iloc[0])
    ).add_to(map)

f.add_child(map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3999e4dab9ce0a398edf6fe30f448d47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3999e4dab9ce0a398edf6fe30f448d47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3999e4dab9ce0a398edf6fe30f448d47 = L.map(
#                 &quot;map_3999e4dab9ce0a398edf6fe30f448d47&quot;,
#                 {
#                     center: [39.4502730411, -0.333362],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5184ffac4ad34238e88e4a6b9d7d0ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_e5184ffac4ad34238e88e4a6b9d7d0ef.addTo(map_3999e4dab9ce0a398edf6fe30f448d47);
#
#
#             var circle_cf5b42fc68d9dc751bc86ff761fb3852 = L.circle(
#                 [39.45878127329601, -0.3586583378805894],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 100.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3999e4dab9ce0a398edf6fe30f448d47);
#
#
#             circle_cf5b42fc68d9dc751bc86ff761fb3852.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901622 | Docks: 20.0 | Cluster: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_34e3ccbf3b3f113fe190f65b71dd4d27 = L.circle(
#                 [39.47228231067077, -0.343809277423822],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 190.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3999e4dab9ce0a398edf6fe30f448d47);
#
#
#             circle_34e3ccbf3b3f113fe190f65b71dd4d27.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901673 | Docks: 38.0 | Cluster: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_cac5ec6127566cb394598737a7b0fad2 = L.circle(
#                 [39.47306831276613, -0.3431322739648798],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 115.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3999e4dab9ce0a398edf6fe30f448d47);
#
#
#             circle_cac5ec6127566cb394598737a7b0fad2.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901677 | Docks: 23.0 | Cluster: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_e4cab30c89832aac72c6c673e2961081 = L.circle(
#                 [39.47134430635022, -0.3404842660990001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 105.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3999e4dab9ce0a398edf6fe30f448d47);
#
#
#             circle_e4cab30c89832aac72c6c673e2961081.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901679 | Docks: 21.0 | Cluster: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_7100dae89c978fa9cda3d2e431c19014 = L.circle(
#                 [39.45651226440267, -0.3554183288036281],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 100.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# ## Make beach stations into separate cluster
# Because Kmeans usually did not put beach station in a separate cluster we will do it independently.

# %%
# List of GIDs of stations near beach
beach_stations = [901750, 901749, 901747, 901745, 901744, 901743, 901856, 901751, 901748, 901746, 901734, 901738]

# Update cluster for stations near beach
locations.loc[locations['gid'].isin(beach_stations), 'cluster'] = k_clusters

k_clusters += 1

# %%
f = folium.Figure(width=700, height=700)
map = folium.Map(location=[39.4502730411, -0.333362], tiles='OpenStreetMap', zoom_start=12)

colors = ['blue', 'red', 'green', 'orange', 'purple', 'magenta', 'brown', 'cyan', 'black', 'darkred', 'gray']

for station in stations:
    folium.Circle(
        location=[locations[locations.gid == station]['lat'].iloc[0], locations[locations.gid == station]['long'].iloc[0]],
        color=colors[locations[locations.gid == station]['cluster'].iloc[0]],
        radius=5 * stations_size.loc[station],
        fill=True,
        opacity=0.8,
        fill_opacity=0.2,
        tooltip='Station {} | Docks: {} | Cluster: {}'.format(
            station, stations_size.loc[station], locations[locations.gid == station]['cluster'].iloc[0])
    ).add_to(map)

f.add_child(map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7072c5db00f1b7b13e8b721d653d85d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7072c5db00f1b7b13e8b721d653d85d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7072c5db00f1b7b13e8b721d653d85d = L.map(
#                 &quot;map_b7072c5db00f1b7b13e8b721d653d85d&quot;,
#                 {
#                     center: [39.4502730411, -0.333362],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_60389534c9464334c25e341247ba36af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_60389534c9464334c25e341247ba36af.addTo(map_b7072c5db00f1b7b13e8b721d653d85d);
#
#
#             var circle_9e992fa53c98c1a5be1e4a4388585481 = L.circle(
#                 [39.45878127329601, -0.3586583378805894],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 100.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7072c5db00f1b7b13e8b721d653d85d);
#
#
#             circle_9e992fa53c98c1a5be1e4a4388585481.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901622 | Docks: 20.0 | Cluster: 1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_757ec53bd0a85e0e710852ed870438de = L.circle(
#                 [39.47228231067077, -0.343809277423822],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 190.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7072c5db00f1b7b13e8b721d653d85d);
#
#
#             circle_757ec53bd0a85e0e710852ed870438de.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901673 | Docks: 38.0 | Cluster: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_75863fafdcdc8c7643973b569e198f1b = L.circle(
#                 [39.47306831276613, -0.3431322739648798],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 115.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7072c5db00f1b7b13e8b721d653d85d);
#
#
#             circle_75863fafdcdc8c7643973b569e198f1b.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901677 | Docks: 23.0 | Cluster: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_ae5530c1c6c2d8f32cc933e56bf1b36b = L.circle(
#                 [39.47134430635022, -0.3404842660990001],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 105.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b7072c5db00f1b7b13e8b721d653d85d);
#
#
#             circle_ae5530c1c6c2d8f32cc933e56bf1b36b.bindTooltip(
#                 `&lt;div&gt;
#                      Station 901679 | Docks: 21.0 | Cluster: 3
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_5708702c6c27c868f379d5c97b5c3208 = L.circle(
#                 [39.45651226440267, -0.3554183288036281],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 0.8, &quot;radius&quot;: 100.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}

# %% [markdown]
# ## Save the dataset

# %%
# Joining the dataframes on gid to get cluster information
data = pd.merge(data, locations, on='gid', how='left')

# Merge lat_x and lat_y into one column 'lat'
data['lat'] = data.apply(lambda row: row['lat_x'] if pd.notnull(row['lat_x']) else row['lat_y'], axis=1)

# Merge long_x and long_y into one column 'long'
data['long'] = data.apply(lambda row: row['long_x'] if pd.notnull(row['long_x']) else row['long_y'], axis=1)

# Drop lat_x, lat_y, long_x, long_y columns
data.drop(['lat_x', 'lat_y', 'long_x', 'long_y'], axis=1, inplace=True)

data.head()
# Out:
#       gid  available  free  total  w_temp           w_sky  w_precip  w_humid  \
# 0  901622         18     2     20    12.0  Cielo cubierto       0.0     66.0
# 1  901673          9    29     38    12.0  Cielo cubierto       0.0     66.0
# 2  901677         15     8     23    12.0  Cielo cubierto       0.0     66.0
# 3  901679          3    18     21    12.0  Cielo cubierto       0.0     66.0
# 4  901627         15     4     20    12.0  Cielo cubierto       0.0     66.0
#
#    w_wind_speed  w_clouds  ...  day_category day_motive             datetime  \
# 0           6.8      88.0  ...   Working day        NaN  2022-12-01 02:00:00
# 1           6.8      88.0  ...   Working day        NaN  2022-12-01 02:00:00
# 2           6.8      88.0  ...   Working day        NaN  2022-12-01 02:00:00
# 3           6.8      88.0  ...   Working day        NaN  2022-12-01 02:00:00
# 4           6.8      88.0  ...   Working day        NaN  2022-12-01 02:00:00
#
#   occupancy   vacancy  bikes_diff  free_diff  cluster        lat      long
# 0  0.900000  0.100000         0.0        0.0        1  39.458781 -0.358658
# 1  0.236842  0.763158         0.0        0.0        3  39.472282 -0.343809
# 2  0.652174  0.347826         0.0        0.0        3  39.473068 -0.343132
# 3  0.142857  0.857143         0.0        0.0        3  39.471344 -0.340484
# 4  0.750000  0.200000         0.0        0.0        1  39.456512 -0.355418
#
# [5 rows x 22 columns]

# %%
data.to_csv('./datasets/data_pos_group.csv', index=False)
